# %%
from sionna.rt import load_scene, Transmitter, Receiver, PlanarArray, PathSolver
import os

scene = load_scene(os.path.expanduser(
    "~/ns-allinone-3.40/ns-3.40/contrib/sionna/model/ns3sionna/models/warehouse/warehouse.xml"),
    merge_shapes=False)
scene.frequency = 5.18e9
scene.bandwidth = 20e6

scene.add(Transmitter("drone_0", position=[-3.0, 0.0, 4.0]))
scene.add(Receiver("drone_1", position=[0.0, 0.0, 5.0]))
scene.add(Receiver("drone_2", position=[3.0, 0.0, 6.0]))

scene.tx_array = PlanarArray(1, 1, 0.5, 0.5, "dipole", "V")
scene.rx_array = PlanarArray(1, 1, 0.5, 0.5, "dipole", "V")

paths = PathSolver()(scene=scene, max_depth=3, samples_per_src=10**6,
                     los=True, specular_reflection=True, refraction=True)

scene.preview(paths=paths, show_devices=True, clip_at=5.9)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 14
#      11 scene.add(Receiver("drone_1", position=[0.0, 0.0, 5.0]))
#      12 scene.add(Receiver("drone_2", position=[3.0, 0.0, 6.0]))
# ---> 14 scene.tx_array = PlanarArray(1, 1, 0.5, 0.5, "dipole", "V")
#      15 scene.rx_array = PlanarArray(1, 1, 0.5, 0.5, "dipole", "V")
#      17 paths = PathSolver()(scene=scene, max_depth=3, samples_per_src=10**6,
#      18                      los=True, specular_reflection=True, refraction=True)
#
# TypeError: PlanarArray.__init__() takes 1 positional argument but 7 were given
